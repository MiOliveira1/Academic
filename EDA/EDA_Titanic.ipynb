# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("titanic")
pd.set_option('display.max_columns', None) #chamar o dataset noutro formato

# %%
print(df) #daqui conseguimos tirar linhas x colunas também
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head(10) #primeiras 10 linhas
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.tail(10) #últimas 10 linhas
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
df.columns #nomes das colunas
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.dtypes #tipos de variáveis das colunas
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df['age'] = pd.to_numeric(df['age']) #perguntar porque é que não alterou o tipo

# %%
df['age'] = df['age'].astype('int64') #trocou com este comando

# %%
df.dtypes #verificação
# Out:
# survived      int64
# pclass        int64
# sex          object
# age           int64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# who          object
# alone          bool
# dtype: object

# %%
df.isnull().sum() #dá-nos os nulos de cada coluna 

#achamos redundante survived - class / pclass - class /sex - adult male /embarked - embark_town
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.countplot(x=df['who']) #esta coluna não é redundante pois dá-nos a categoria crianças, além de homens e mulheres
# Out:
# <AxesSubplot:xlabel='who', ylabel='count'>

# %%
sns.scatterplot(df['pclass'], df['deck']) #análise da relação entre pclass e deck

#concluimos que as duas variáveis estão relacionadas não exclusivamente, mas estão. Uma vez que a quantidade de nulos também é muito significativa, vamos eliminar esta coluna
# Out:
# C:\Users\PTL14736\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='deck'>

# %%
np.where(df['embarked'].isnull()) #localização dos dois nulos da coluna embarked
# Out:
# (array([ 61, 829], dtype=int64),)

# %%
df = df.drop(labels = [61,829], axis=0) #eliminação das 2 linhas com nulos correspondentes à coluna embarked

# %%
df.isnull().sum() #verificação
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
df = df.drop(columns=['deck', 'alive', 'embark_town', 'class']) #eliminação das colunas que consideramos redundantes

# %%
df.isnull().sum() #verificação
# Out:
# survived        0
# pclass          0
# sex             0
# age           177
# sibsp           0
# parch           0
# fare            0
# embarked        0
# who             0
# adult_male      0
# alone           0
# dtype: int64

# %%
sns.countplot(x=df['adult_male'])
# Out:
# <AxesSubplot:xlabel='adult_male', ylabel='count'>

# %%
df['adult_male'].value_counts()
# Out:
# True     537
# False    352
# Name: adult_male, dtype: int64

# %%
sns.countplot(x=df['who'])
# Out:
# <AxesSubplot:xlabel='who', ylabel='count'>

# %%
df['who'].value_counts() #concluimos que a coluna adult male também é redundante pelo que vamos eliminar também
# Out:
# man      537
# woman    269
# child     83
# Name: who, dtype: int64

# %%
df = df.drop(columns = ['adult_male']) #eliminação da coluna

# %%
df.columns #verificação das colunas após eliminação
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'who', 'alone'],
#       dtype='object')

# %%
print(df.loc[(df['embarked'].isnull())]) #localização dos nulos embarcados - 2ª verificação
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, who, alone]
# Index: []

# %%
df.loc[(df['who']=='child') & df['age'].isnull()] #localização das criação com idades a nulos
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, who, alone]
# Index: []

# %%
df.loc[(df['who']=='man') & df['age'].isnull()] #localização dos homens com idades a nulos
# Out:
#      survived  pclass   sex  age  sibsp  parch     fare embarked  who  alone
# 5           0       3  male  NaN      0      0   8.4583        Q  man   True
# 17          1       2  male  NaN      0      0  13.0000        S  man   True
# 26          0       3  male  NaN      0      0   7.2250        C  man   True
# 29          0       3  male  NaN      0      0   7.8958        S  man   True
# 36          1       3  male  NaN      0      0   7.2292        C  man   True
# ..        ...     ...   ...  ...    ...    ...      ...      ...  ...    ...
# 839         1       1  male  NaN      0      0  29.7000        C  man   True
# 846         0       3  male  NaN      8      2  69.5500        S  man  False
# 859         0       3  male  NaN      0      0   7.2292        C  man   True
# 868         0       3  male  NaN      0      0   9.5000        S  man   True
# 878         0       3  male  NaN      0      0   7.8958        S  man   True
#
# [124 rows x 10 columns]

# %%
len(df.loc[(df['who']=='man') & df['age'].isnull()]) #quantidade 124
# Out:
# 124

# %%
df.loc[(df['who']=='woman') & df['age'].isnull()] #localização das mulheres com idades a nulos
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked    who  \
# 19          1       3  female  NaN      0      0    7.2250        C  woman
# 28          1       3  female  NaN      0      0    7.8792        Q  woman
# 31          1       1  female  NaN      1      0  146.5208        C  woman
# 32          1       3  female  NaN      0      0    7.7500        Q  woman
# 47          1       3  female  NaN      0      0    7.7500        Q  woman
# 82          1       3  female  NaN      0      0    7.7875        Q  woman
# 109         1       3  female  NaN      1      0   24.1500        Q  woman
# 128         1       3  female  NaN      1      1   22.3583        C  woman
# 140         0       3  female  NaN      0      2   15.2458        C  woman
# 166         1       1  female  NaN      0      1   55.0000        S  woman
# 180         0       3  female  NaN      8      2   69.5500        S  woman
# ...

# %%
len(df.loc[(df['who']=='woman') & df['age'].isnull()]) #quantidade 53 - total 177
# Out:
# 53

# %%
df.loc[(df['who']=='woman') & (df['survived']==1)].describe() #descrição das mulheres que sobreviveram
# Out:
#        survived      pclass         age       sibsp       parch        fare
# count     203.0  203.000000  167.000000  203.000000  203.000000  203.000000
# mean        1.0    1.847291   32.236527    0.482759    0.448276   54.565661
# std         0.0    0.827336   11.594532    0.698973    0.809005   66.465819
# min         1.0    1.000000   16.000000    0.000000    0.000000    7.225000
# 25%         1.0    1.000000   23.000000    0.000000    0.000000   13.000000
# 50%         1.0    2.000000   30.000000    0.000000    0.000000   26.000000
# 75%         1.0    3.000000   39.000000    1.000000    1.000000   77.958300
# max         1.0    3.000000   63.000000    4.000000    5.000000  512.329200

# %%
a= df.loc[(df['who']=='woman') & (df['survived']==1)].median() #cálculo da mediana
# Out:
# C:\Users\PTL14736\AppData\Local\Temp\ipykernel_21036\2184318252.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   a= df.loc[(df['who']=='woman') & (df['survived']==1)].median() #cálculo da mediana

# %%
print(a) #mediana da age das mulheres que sobreviveram é 30
# Out:
# survived     1.0
# pclass       2.0
# age         30.0
# sibsp        0.0
# parch        0.0
# fare        26.0
# alone        0.0
# dtype: float64

# %%
df.loc[(df['who']=='woman') & (df['survived']==1)].fillna(30, inplace = True) #fill NaN with value (mediana) - mas este comando não funciona não sei porquê
# Out:
# C:\Users\PTL14736\AppData\Local\Temp\ipykernel_21036\3950900072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[(df['who']=='woman') & (df['survived']==1)].fillna(30, inplace = True) #fill NaN with value (mediana) - mas este comando não funciona não sei porquê

# %%
median_woman = df.loc[(df['who']=='woman') ].median() #cálculo da mediana das mulheres
# Out:
# C:\Users\PTL14736\AppData\Local\Temp\ipykernel_21036\1941018737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   median_woman = df.loc[(df['who']=='woman') ].median() #cálculo da mediana das mulheres

# %%
print(median_woman) #mediana da idade é 30
# Out:
# survived     1.0
# pclass       2.0
# age         30.0
# sibsp        0.0
# parch        0.0
# fare        23.0
# alone        0.0
# dtype: float64

# %%
median_man = df.loc[(df['who']=='man')].median() #cálculo da mediana dos homens
# Out:
# C:\Users\PTL14736\AppData\Local\Temp\ipykernel_21036\1960421956.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   median_man = df.loc[(df['who']=='man')].median() #cálculo da mediana dos homens

# %%
print(median_man) #mediana da idade é igual 30
# Out:
# survived     0.0
# pclass       3.0
# age         30.0
# sibsp        0.0
# parch        0.0
# fare         9.5
# alone        1.0
# dtype: float64

# %%
median_child = df.loc[(df['who']=='child')].median() #cálculo da mediana das crianças
# Out:
# C:\Users\PTL14736\AppData\Local\Temp\ipykernel_21036\3183332905.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   median_child = df.loc[(df['who']=='child')].median() #cálculo da mediana das crianças

# %%
print(median_child) #mediana da idade é 5
# Out:
# survived     1.00
# pclass       3.00
# age          5.00
# sibsp        1.00
# parch        1.00
# fare        26.25
# alone        0.00
# dtype: float64

# %%
df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# embarked      0
# who           0
# alone         0
# dtype: int64

# %%
df.loc[(df['who']=='woman') & df['age'].isnull()] = df.loc[(df['who']=='woman') & df['age'].isnull()].replace(np.nan,30) #substituição dos valores nan pela mediana

# %%
df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         124
# sibsp         0
# parch         0
# fare          0
# embarked      0
# who           0
# alone         0
# dtype: int64

# %%
df.head(20) #verificação
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0          0       3    male  22.0      1      0   7.2500        S    man
# 1          1       1  female  38.0      1      0  71.2833        C  woman
# 2          1       3  female  26.0      0      0   7.9250        S  woman
# 3          1       1  female  35.0      1      0  53.1000        S  woman
# 4          0       3    male  35.0      0      0   8.0500        S    man
# 5          0       3    male   NaN      0      0   8.4583        Q    man
# 6          0       1    male  54.0      0      0  51.8625        S    man
# 7          0       3    male   2.0      3      1  21.0750        S  child
# 8          1       3  female  27.0      0      2  11.1333        S  woman
# 9          1       2  female  14.0      1      0  30.0708        C  child
# 10         1       3  female   4.0      1      1  16.7000        S  child
# 11         1       1  female  58.0      0      0  26.5500        S  woman
# ...

# %%
df.loc[(df['who']=='man') & df['age'].isnull()] = df.loc[(df['who']=='man') & df['age'].isnull()].replace(np.nan,30) #substituição dos valores nan pela mediana

# %%
df.isnull().sum() #verificação
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# who         0
# alone       0
# dtype: int64

# %%
df.dtypes #tipos de variáveis das colunas
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# who          object
# alone          bool
# dtype: object

# %%
df['age'] = df['age'].astype('int64') #alteração do tipo de variável da idade de float para inteiro

# %%
df.dtypes
# Out:
# survived      int64
# pclass        int64
# sex          object
# age           int64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# who          object
# alone          bool
# dtype: object

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'survived'}>,
#         <AxesSubplot:title={'center':'pclass'}>],
#        [<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sibsp'}>],
#        [<AxesSubplot:title={'center':'parch'}>,
#         <AxesSubplot:title={'center':'fare'}>]], dtype=object)

# %%
df.loc[(df['who']=='woman') & (df['survived']==0)].describe() #descrição das mulheres que morreram
# Out:
#        survived     pclass        age      sibsp      parch        fare
# count      66.0  66.000000  66.000000  66.000000  66.000000   66.000000
# mean        0.0   2.848485  30.333333   0.984848   0.939394   20.967174
# std         0.0   0.438263   9.030433   1.801644   1.487163   22.017519
# min         0.0   1.000000  16.000000   0.000000   0.000000    6.750000
# 25%         0.0   3.000000  24.250000   0.000000   0.000000    8.268750
# 50%         0.0   3.000000  30.000000   0.000000   0.000000   14.454200
# 75%         0.0   3.000000  31.750000   1.000000   1.750000   25.466700
# max         0.0   3.000000  57.000000   8.000000   6.000000  151.550000

# %%
plt.figure(figsize=(10,10))
ax = sns.countplot(x='pclass', data=df.loc[(df['who']=='woman') & (df['survived']==0)])
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2'), Text(0, 0, '6'), Text(0, 0, '58')]

# %%
df.loc[(df['who']=='man') & (df['survived']==1)].describe() #descrição dos homens que sobreviveram
# Out:
#        survived     pclass        age      sibsp      parch        fare
# count      88.0  88.000000  88.000000  88.000000  88.000000   88.000000
# mean        1.0   1.954545  33.329545   0.261364   0.125000   42.076422
# std         0.0   0.957836  10.876233   0.491171   0.395739   77.423374
# min         1.0   1.000000  16.000000   0.000000   0.000000    0.000000
# 25%         1.0   1.000000  27.000000   0.000000   0.000000    8.050000
# 50%         1.0   2.000000  30.000000   0.000000   0.000000   26.337500
# 75%         1.0   3.000000  36.250000   0.000000   0.000000   52.554200
# max         1.0   3.000000  80.000000   2.000000   2.000000  512.329200

# %%
plt.figure(figsize=(10,10))
ax = sns.countplot(x='pclass', data=df.loc[(df['who']=='man') & (df['survived']==1)])
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '42'), Text(0, 0, '8'), Text(0, 0, '38')]

# %%
df.loc[(df['who']=='man') & (df['survived']==0)].describe() #descrição dos homens que morreram
# Out:
#        survived      pclass         age       sibsp       parch        fare
# count     449.0  449.000000  449.000000  449.000000  449.000000  449.000000
# mean        0.0    2.454343   32.249443    0.302895    0.158129   21.490736
# std         0.0    0.769558   11.490491    0.904856    0.550513   32.937005
# min         0.0    1.000000   16.000000    0.000000    0.000000    0.000000
# 25%         0.0    2.000000   25.000000    0.000000    0.000000    7.775000
# 50%         0.0    3.000000   30.000000    0.000000    0.000000    8.662500
# 75%         0.0    3.000000   36.000000    0.000000    0.000000   24.150000
# max         0.0    3.000000   74.000000    8.000000    5.000000  263.000000

# %%
df.loc[(df['who']=='child') & (df['survived']==1)].describe() #descrição das crianças que sobreviveram
# Out:
#        survived     pclass        age      sibsp      parch        fare
# count      49.0  49.000000  49.000000  49.000000  49.000000   49.000000
# mean        1.0   2.408163   5.673469   0.836735   1.163265   32.891329
# std         0.0   0.674486   4.997448   0.920755   0.687597   39.126838
# min         1.0   1.000000   0.000000   0.000000   0.000000    7.225000
# 25%         1.0   2.000000   2.000000   0.000000   1.000000   14.454200
# 50%         1.0   3.000000   4.000000   1.000000   1.000000   20.525000
# 75%         1.0   3.000000   9.000000   1.000000   2.000000   31.387500
# max         1.0   3.000000  15.000000   4.000000   2.000000  211.337500

# %%
df.loc[(df['who']=='child') & (df['survived']==0)].describe() #descrição das crianças que morreram
# Out:
#        survived     pclass        age      sibsp      parch        fare
# count      34.0  34.000000  34.000000  34.000000  34.000000   34.000000
# mean        0.0   2.941176   7.205882   3.029412   1.411765   32.633703
# std         0.0   0.342997   4.409215   1.585642   0.656790   23.584291
# min         0.0   1.000000   1.000000   0.000000   0.000000    7.229200
# 25%         0.0   3.000000   2.250000   2.250000   1.000000   21.843750
# 50%         0.0   3.000000   8.000000   4.000000   1.500000   29.125000
# 75%         0.0   3.000000  10.000000   4.000000   2.000000   38.359375
# max         0.0   3.000000  15.000000   5.000000   2.000000  151.550000

# %%
#correlação abaixo de 0,4 não tem grande significado 
corr=df.corr(method='pearson')
print(corr)
# Out:
#           survived    pclass       age     sibsp     parch      fare     alone
# survived  1.000000 -0.335549 -0.075504 -0.034040  0.083151  0.255290 -0.206207
# pclass   -0.335549  1.000000 -0.326437  0.081656  0.016824 -0.548193  0.138553
# age      -0.075504 -0.326437  1.000000 -0.231451 -0.179630  0.087825  0.179260
# sibsp    -0.034040  0.081656 -0.231451  1.000000  0.414542  0.160887 -0.584186
# parch     0.083151  0.016824 -0.179630  0.414542  1.000000  0.217532 -0.583112
# fare      0.255290 -0.548193  0.087825  0.160887  0.217532  1.000000 -0.274079
# alone    -0.206207  0.138553  0.179260 -0.584186 -0.583112 -0.274079  1.000000

# %%
sns.heatmap(corr.round(2),annot=True)
plt.savefig('heatmap',dpi=300,bbox_inches='tight')

# %%
sns.scatterplot(df['age'], df['pclass'])
# Out:
# C:\Users\PTL14736\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='pclass'>

# %%
sns.regplot(x=df['age'], y=df['pclass'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='pclass'>

# %%
sns.boxplot(x=df['survived'], y=df['age'])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>
